# %%
import requests
from PIL import Image
import json

# %%
subscription_key ='6ff9cda2be81458abbbbd8b69d3f58a1'

# %%
assert subscription_key

# %%
face_api_url ='https://yoshifacerec.cognitiveservices.azure.com/face/v1.0/detect'

# %%
img1=Image.open('f1.png')
img1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=423x324 at 0x15843EB5188>

# %%
with open('f1.png','rb') as f:
    binary_img= f.read()

# %%
# binary_img

# %%
headers = {
    'Content-Type':'application/octet-stream',
    'Ocp-Apim-Subscription-Key': subscription_key 
}

params = {
    'returnFaceId':'true',
     'returnFaceLandmarks': 'false',
    'returnFaceAttributes': 'age,gender,headPose,smile,facialHair,glasses,emotion,hair,makeup,occlusion,accessories,blur,exposure,noise'

}

res =requests.post(face_api_url,params=params,
                       headers=headers,data=binary_img)

# %%
res
# Out:
# <Response [200]>

# %%
result =res.json()
result
# Out:
# [{'faceId': '4d5eb01d-fb47-4925-b610-e9d1171be125',
#   'faceRectangle': {'top': 67, 'left': 76, 'width': 249, 'height': 249},
#   'faceAttributes': {'smile': 0.291,
#    'headPose': {'pitch': -11.8, 'roll': 0.3, 'yaw': -16.3},
#    'gender': 'female',
#    'age': 23.0,
#    'facialHair': {'moustache': 0.0, 'beard': 0.0, 'sideburns': 0.0},
#    'glasses': 'NoGlasses',
#    'emotion': {'anger': 0.0,
#     'contempt': 0.002,
#     'disgust': 0.0,
#     'fear': 0.0,
#     'happiness': 0.291,
#     'neutral': 0.706,
#     'sadness': 0.0,
#     'surprise': 0.0},
#    'blur': {'blurLevel': 'low', 'value': 0.0},
#    'exposure': {'exposureLevel': 'overExposure', 'value': 0.84},
#    'noise': {'noiseLevel': 'low', 'value': 0.04},
#    'makeup': {'eyeMakeup': True, 'lipMakeup': True},
#    'accessories': [],
#    'occlusion': {'foreheadOccluded': False,
#     'eyeOccluded': False,
#     'mouthOccluded': False},
#    'hair': {'bald': 0.46,
#     'invisible': False,
#     'hairColor': [{'color': 'brown', 'confidence': 0.98},
#      {'color': 'blond', 'confidence': 0.9},
#      {'color': 'red', 'confidence': 0.31},
#      {'color': 'gray', 'confidence': 0.21},
#      {'color': 'black', 'confidence': 0.17},
#      {'color': 'other', 'confidence': 0.09},
#      {'color': 'white', 'confidence': 0.0}]}}}]

# %%
rect =result[0]['faceRectangle']
rect
# Out:
# {'top': 67, 'left': 76, 'width': 249, 'height': 249}

# %%
from PIL import ImageDraw

# %%
draw =ImageDraw.Draw(img1)

# %%
# draw.line([(0,50),(200,50),(0,150),(200,150)],fill='blue',width=5)
img1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=423x324 at 0x15843EB5188>

# %%
draw.rectangle([(rect['left'],rect['top']),(rect['left']+rect['width'],rect['top']+rect['height'])],fill=None,outline='green',width=5)

# %%
img1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=423x324 at 0x15843EB5188>

# %%
import requests
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont
import io
import json


    
subscription_key ='6ff9cda2be81458abbbbd8b69d3f58a1'
assert subscription_key

face_api_url ='https://yoshifacerec.cognitiveservices.azure.com/face/v1.0/detect'

img1=Image.open('f2.png')
with open('f2.png','rb') as f:
    binary_img= f.read()

headers = {
    'Content-Type':'application/octet-stream',
    'Ocp-Apim-Subscription-Key': subscription_key 
}

params = {
    'returnFaceId':'true',
    'returnFaceAttributes': 'age,gender,headPose,smile,facialHair,glasses,emotion,hair,makeup,occlusion,accessories,blur,exposure,noise'

}

res =requests.post(face_api_url,params=params,
                       headers=headers,data=binary_img)    

results =res.json()
for result in results:
    rect =result['faceRectangle']
#     age =result['age']
  
    
    draw =ImageDraw.Draw(img1)    
    draw.rectangle([(rect['left'],rect['top']),(rect['left']+rect['width'],rect['top']+rect['height'])],fill=None,outline='green',width=5)
    
    font_size = 24
    font_name = "C:\Windows\Fonts\meiryo.ttc"
    src = r"pillow_test_src.png"
    dest= r"pillow_test_dest.png"
    draw_x = 140
    draw_y = 120
#     text = draw.age
    font = ImageFont.truetype(font_name, font_size)
#     draw.text((draw_x, draw_y), text, font=font, fill=(255,0,0,128))
    
img1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=593x385 at 0x2293355FC88>

# %%
results[2]
# Out:
# {'faceId': 'ba9462ce-2dbb-4e72-aa15-4f410d74ccdb',
#  'faceRectangle': {'top': 130, 'left': 427, 'width': 98, 'height': 98},
#  'faceAttributes': {'smile': 1.0,
#   'headPose': {'pitch': 0.6, 'roll': -21.6, 'yaw': 6.2},
#   'gender': 'female',
#   'age': 26.0,
#   'facialHair': {'moustache': 0.0, 'beard': 0.0, 'sideburns': 0.0},
#   'glasses': 'NoGlasses',
#   'emotion': {'anger': 0.0,
#    'contempt': 0.0,
#    'disgust': 0.0,
#    'fear': 0.0,
#    'happiness': 1.0,
#    'neutral': 0.0,
#    'sadness': 0.0,
#    'surprise': 0.0},
#   'blur': {'blurLevel': 'medium', 'value': 0.27},
#   'exposure': {'exposureLevel': 'goodExposure', 'value': 0.71},
#   'noise': {'noiseLevel': 'low', 'value': 0.05},
#   'makeup': {'eyeMakeup': True, 'lipMakeup': True},
#   'accessories': [],
#   'occlusion': {'foreheadOccluded': False,
#    'eyeOccluded': False,
#    'mouthOccluded': False},
#   'hair': {'bald': 0.14,
#    'invisible': False,
#    'hairColor': [{'color': 'brown', 'confidence': 0.99},
#     {'color': 'black', 'confidence': 0.98},
#     {'color': 'gray', 'confidence': 0.24},
#     {'color': 'other', 'confidence': 0.12},
#     {'color': 'blond', 'confidence': 0.09},
#     {'color': 'red', 'confidence': 0.07},
#     {'color': 'white', 'confidence': 0.0}]}}}

# %%
with io.BytesIO() as output:
    img1.save(output,fortmat="JPEG")
    binary_img =output.getvalue()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2081             try:
# -> 2082                 format = EXTENSION[ext]
#    2083             except KeyError:
#
# KeyError: ''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-a3650c428fe4> in <module>
#       1 with io.BytesIO() as output:
# ----> 2     img1.save(output,fortmat="JPEG")
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2082                 format = EXTENSION[ext]
#    2083             except KeyError:
# -> 2084                 raise ValueError("unknown file extension: {}".format(ext))
#    2085
#    2086         if format.upper() not in SAVE:
#
# ValueError: unknown file extension:

# %%
io.BytesIO()
